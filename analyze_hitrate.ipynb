# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Load the hit rate data
with open('/data/mert_cemri/new/CS262_moe/run_712378/hit_rate_summary_upto_step_284.json', 'r') as f:
    hit_rate_data = json.load(f)

# Group hit rates by step
hit_rates_by_step = defaultdict(list)
for entry in hit_rate_data:
    hit_rates_by_step[entry['step']].append(entry['hit_rate'])

# Calculate average hit rate per step
steps = sorted(hit_rates_by_step.keys())
avg_hit_rates = [np.mean(hit_rates_by_step[step]) for step in steps]

# Create histogram of hit rates for each step
# Create a histogram of all hit rates
plt.figure(figsize=(12, 8))

# Extract all hit rates from the data
all_hit_rates = [entry['hit_rate'] for entry in hit_rate_data]

# Create histogram with 10 bins from 0 to 1
bins = np.linspace(0, 1, 11)  # Creates 10 bins: 0-0.1, 0.1-0.2, ..., 0.9-1.0
plt.hist(all_hit_rates, bins=bins, alpha=0.7, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Hit Rate', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Hit Rates (0 to 1)', fontsize=14)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add vertical line for the mean
plt.axvline(x=overall_avg, color='r', linestyle='--', 
            label=f'Mean: {overall_avg:.3f}')

# Add vertical line for the median
median_hit_rate = np.median(all_hit_rates)
plt.axvline(x=median_hit_rate, color='g', linestyle='-.',
            label=f'Median: {median_hit_rate:.3f}')

# Add text with statistics
stats_text = (f"Total samples: {len(all_hit_rates)}\n"
              f"Mean: {overall_avg:.3f}\n"
              f"Median: {median_hit_rate:.3f}\n"
              f"Min: {min(all_hit_rates):.3f}\n"
              f"Max: {max(all_hit_rates):.3f}")
plt.annotate(stats_text, xy=(0.75, 0.75), xycoords='axes fraction', 
             bbox=dict(boxstyle="round,pad=0.5", facecolor='white', alpha=0.8))

plt.legend()
plt.tight_layout()
plt.show()
print(f"Step with highest average hit rate: {steps[np.argmax(avg_hit_rates)]} ({max(avg_hit_rates):.4f})")
# Out:
# Step with highest average hit rate: 3 (1.0000)

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Load the hit rate data
with open('/data/mert_cemri/new/CS262_moe/run_712439/hit_rate_summary_upto_step_284.json', 'r') as f:
    hit_rate_data = json.load(f)

# Group hit rates by step
hit_rates_by_step = defaultdict(list)
for entry in hit_rate_data:
    hit_rates_by_step[entry['step']].append(entry['hit_rate'])

# Calculate average hit rate per step
steps = sorted(hit_rates_by_step.keys())
avg_hit_rates = [np.mean(hit_rates_by_step[step]) for step in steps]

# Create histogram of hit rates for each step
# Create a histogram of all hit rates
plt.figure(figsize=(12, 8))

# Extract all hit rates from the data
all_hit_rates = [entry['hit_rate'] for entry in hit_rate_data]

# Create histogram with 10 bins from 0 to 1
bins = np.linspace(0, 1, 11)  # Creates 10 bins: 0-0.1, 0.1-0.2, ..., 0.9-1.0
plt.hist(all_hit_rates, bins=bins, alpha=0.7, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Hit Rate', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Hit Rates (0 to 1)', fontsize=14)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add vertical line for the mean
plt.axvline(x=overall_avg, color='r', linestyle='--', 
            label=f'Mean: {overall_avg:.3f}')

# Add vertical line for the median
median_hit_rate = np.median(all_hit_rates)
plt.axvline(x=median_hit_rate, color='g', linestyle='-.',
            label=f'Median: {median_hit_rate:.3f}')

# Add text with statistics
stats_text = (f"Total samples: {len(all_hit_rates)}\n"
              f"Mean: {overall_avg:.3f}\n"
              f"Median: {median_hit_rate:.3f}\n"
              f"Min: {min(all_hit_rates):.3f}\n"
              f"Max: {max(all_hit_rates):.3f}")
plt.annotate(stats_text, xy=(0.75, 0.75), xycoords='axes fraction', 
             bbox=dict(boxstyle="round,pad=0.5", facecolor='white', alpha=0.8))

plt.legend()
plt.tight_layout()
plt.show()
print(f"Step with highest average hit rate: {steps[np.argmax(avg_hit_rates)]} ({max(avg_hit_rates):.4f})")
# Out:
# Step with highest average hit rate: 174 (0.3426)

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
from collections import defaultdict

# Load the hit rate data
with open('/data/mert_cemri/new/CS262_moe/run_712439/hit_rate_summary_upto_step_284.json', 'r') as f:
    hit_rate_data = json.load(f)

# Group hit rates by step
hit_rates_by_step = defaultdict(list)
for entry in hit_rate_data:
    hit_rates_by_step[entry['step']].append(entry['hit_rate'])

# Calculate average hit rate per step
steps = sorted(hit_rates_by_step.keys())
avg_hit_rates = [np.mean(hit_rates_by_step[step]) for step in steps]

# Create histogram of hit rates for each step
# Create a histogram of all hit rates
plt.figure(figsize=(12, 8))

# Extract all hit rates from the data
all_hit_rates = [entry['hit_rate'] for entry in hit_rate_data]

# Create histogram with 10 bins from 0 to 1
bins = np.linspace(0, 1, 11)  # Creates 10 bins: 0-0.1, 0.1-0.2, ..., 0.9-1.0
plt.hist(all_hit_rates, bins=bins, alpha=0.7, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Hit Rate', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Distribution of Hit Rates (0 to 1)', fontsize=14)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add vertical line for the mean
plt.axvline(x=overall_avg, color='r', linestyle='--', 
            label=f'Mean: {overall_avg:.3f}')

# Add vertical line for the median
median_hit_rate = np.median(all_hit_rates)
plt.axvline(x=median_hit_rate, color='g', linestyle='-.',
            label=f'Median: {median_hit_rate:.3f}')

# Add text with statistics
stats_text = (f"Total samples: {len(all_hit_rates)}\n"
              f"Mean: {overall_avg:.3f}\n"
              f"Median: {median_hit_rate:.3f}\n"
              f"Min: {min(all_hit_rates):.3f}\n"
              f"Max: {max(all_hit_rates):.3f}")
plt.annotate(stats_text, xy=(0.75, 0.75), xycoords='axes fraction', 
             bbox=dict(boxstyle="round,pad=0.5", facecolor='white', alpha=0.8))

plt.legend()
plt.tight_layout()
plt.show()
print(f"Step with highest average hit rate: {steps[np.argmax(avg_hit_rates)]} ({max(avg_hit_rates):.4f})")
